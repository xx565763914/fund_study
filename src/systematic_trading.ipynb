# %%
from sysdata.sim.csv_futures_sim_data import csvFuturesSimData
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-19c353064069> in <module>()
# ----> 1 from sysdata.sim.csv_futures_sim_data import csvFuturesSimData
#
# ~/Public/pysystemtrade/sysdata/sim/csv_futures_sim_data.py in <module>()
#       5
#       6 from syscore.objects import arg_not_supplied
# ----> 7 from sysdata.csv.csv_multiple_prices import csvFuturesMultiplePricesData
#       8 from sysdata.csv.csv_adjusted_prices import csvFuturesAdjustedPricesData
#       9 from sysdata.csv.csv_spot_fx import csvFxPricesData
#
# ~/Public/pysystemtrade/sysdata/csv/csv_multiple_prices.py in <module>()
#       1 import pandas as pd
# ----> 2 from sysdata.futures.multiple_prices import (
#       3     futuresMultiplePricesData,
#       4 )
#       5 from sysobjects.multiple_prices import futuresMultiplePrices, list_of_contract_column_names
#
# ...
